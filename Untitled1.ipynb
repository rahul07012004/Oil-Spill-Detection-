# %%
from google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-0ae13fb9-60ec-4d9c-8cce-57a1d61e47e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ae13fb9-60ec-4d9c-8cce-57a1d61e47e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# Assuming 'data_cleaned' is your preprocessed dataset with relevant features
# You can adjust the columns based on your dataset.
file_path = 'AIS_2022_03_31.xlsx'
data = pd.read_excel('AIS_2022_03_31.xlsx')
# Define the features (X) and the target variable (y)
# Replace 'VesselType' with your actual target column
X = data[['LAT', 'LON', 'SOG', 'COG', 'Heading', 'Length', 'Width', 'Draft','MMSI', 'Cargo']]
y = data['Status']
# Drop rows with NaN values in the target variable 'y'
data.dropna(subset=['Status'], inplace=True)

# Redefine X and y after dropping NaN values
X = data[['LAT', 'LON', 'SOG', 'COG', 'Heading', 'Length', 'Width', 'Draft', 'Cargo']]
y = data['Status']


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Standardize the features (optional for Random Forest but may improve performance)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Initialize and train the Random Forest model
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)  # You can tune the n_estimators
rf_model.fit(X_train_scaled, y_train)

# Make predictions on the test data
y_pred = rf_model.predict(X_test_scaled)

# Evaluate the model's performance
accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy: {accuracy:.2f}')
print('\nClassification Report:')
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.99
#
# Classification Report:
#               precision    recall  f1-score   support
#
#          0.0       0.99      1.00      0.99      6154
#          1.0       0.98      0.94      0.96       403
#          2.0       0.96      0.96      0.96        26
#          3.0       0.99      0.99      0.99       174
#          4.0       1.00      1.00      1.00        10
#          5.0       0.99      0.94      0.96      1558
#          6.0       1.00      1.00      1.00         6
#          7.0       1.00      1.00      1.00        47
#          8.0       1.00      0.99      1.00       114
#          9.0       0.94      1.00      0.97        15
#         10.0       1.00      1.00      1.00        19
#         11.0       1.00      0.97      0.99       111
#         12.0       0.99      1.00      0.99      2152
#         13.0       1.00      1.00      1.00        10
#         15.0       0.99      0.99      0.99      1276
#
#     accuracy                           0.99     12075
# ...

# %%
time_series_df=pd.read_excel('AIS_2022_03_31.xlsx')
time_series_df.head()
# Out:
#         MMSI         BaseDateTime       LAT        LON  SOG    COG  Heading  \
# 0  367702220  2022-03-31T00:00:01  29.78763  -95.08070  0.1  226.5      340
# 1  671226100  2022-03-31T00:00:01  25.77626  -80.20320  3.2  143.7      511
# 2  367767250  2022-03-31T00:00:01  29.31623  -94.78829  4.5  228.1      511
# 3  338327436  2022-03-31T00:00:03  47.29634 -122.42233  0.0  360.0      511
# 4  367452810  2022-03-31T00:00:06  29.32824  -94.77391  2.6  319.2      511
#
#        VesselName         IMO CallSign  VesselType  Status  Length  Width  \
# 0      JOE B WARD         NaN  WDI4808        31.0    12.0    21.0    8.0
# 1     RELIANCE II  IMO9221322    5VHS7        79.0     0.0    52.0   12.0
# 2          GLEN K         NaN  WDJ3358        52.0     0.0     0.0    0.0
# 3        COOL KAT  IMO0000000      NaN        36.0     NaN    15.0    3.0
# 4  JOHN W JOHNSON  IMO9602344  WDF4516        60.0     0.0    80.0   19.0
#
#    Draft  Cargo TransceiverClass
# ...

# %%
time_series_df.sort_values(by=['BaseDateTime'], inplace=True)
time_series_df.head()
print(time_series_df.loc[time_series_df['BaseDateTime'] == '2022-03-31T00:00:01'])
# Out:
#            MMSI         BaseDateTime       LAT        LON   SOG    COG  \
# 842   367170860  2022-03-31T00:00:01  46.16843 -123.91411   0.0  360.0
# 1875  368124510  2022-03-31T00:00:01  38.58097  -90.21127   3.9   35.7
# 843   366969140  2022-03-31T00:00:01  29.74010  -95.27991   0.0  264.7
# 841   367586750  2022-03-31T00:00:01  29.96769  -93.85980   0.0   29.5
# 1833  368052910  2022-03-31T00:00:01  30.00928  -89.91921   0.0  250.0
# ...         ...                  ...       ...        ...   ...    ...
# 6511  271045704  2022-03-31T00:00:01  28.22071  -94.40572  11.0  356.9
# 4746  367573820  2022-03-31T00:00:01  45.49602 -124.22016   8.8  192.2
# 2500  367512920  2022-03-31T00:00:01  30.07078  -94.04816   0.0   27.5
# 2502  367760730  2022-03-31T00:00:01  32.80172  -79.93063   0.0  360.0
# 6648  367537450  2022-03-31T00:00:01  30.03880  -90.68496  15.2   46.6
#
#       Heading         VesselName         IMO CallSign  VesselType  Status  \
# ...

# %%
time_sorted_df = time_series_df.sort_values(by=['BaseDateTime'], inplace=True)
time_series_df.head()
time_series_df.head()
time_series_df
time_series_df.info()
time_series_df['BaseDateTime'] = pd.to_datetime(time_series_df['BaseDateTime'], infer_datetime_format=True)
time_series_df.info()
time_series_df.head()
plt.plot( time_series_df['BaseDateTime'], time_series_df['Heading'])
# Check for existing columns before dropping
existing_columns = time_series_df.columns

columns_to_drop = ["CallSign" ,"SOG","Draft" , "Cargo",  "Length", "Width","IMO" , "VesselType", "TransceiverClass"  ]

# Drop only columns that exist in the DataFrame
for col in columns_to_drop:
  if col in existing_columns:
    time_series_df.drop(col, axis=1, inplace=True)

time_series_df.info()
time_series_df.head()

# This line is not needed as 'SOG' has already been removed in the loop above.
#time_series_df.drop(['SOG', 'VesselName'], axis=1, inplace=True)
# Access the MMSI column (no need to drop it)
time_series_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49142 entries, 0 to 49141
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BaseDateTime  49142 non-null  datetime64[ns]
#  1   LAT           49142 non-null  float64
#  2   LON           49142 non-null  float64
#  3   COG           49142 non-null  float64
#  4   Heading       49142 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 2.2 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 49142 entries, 0 to 49141
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BaseDateTime  49142 non-null  datetime64[ns]
#  1   LAT           49142 non-null  float64
#  2   LON           49142 non-null  float64
#  3   COG           49142 non-null  float64
#  4   Heading       49142 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 2.2 MB
# ...

# %%
time_sorted_df = time_series_df.sort_values(by=['BaseDateTime'], inplace=True)
time_series_df.head()
time_series_df.head()
time_series_df
time_series_df.info()
time_series_df['BaseDateTime'] = pd.to_datetime(time_series_df['BaseDateTime'], infer_datetime_format=True)
time_series_df.info()
time_series_df.head()
plt.plot( time_series_df['BaseDateTime'], time_series_df['Heading'])
# Check for existing columns before dropping
existing_columns = time_series_df.columns

# 'MMSI' has been removed from this list
columns_to_drop = ["CallSign" ,"SOG","Draft" , "Cargo",  "Length", "Width","IMO" , "VesselType", "TransceiverClass"  ]

# Drop only columns that exist in the DataFrame
for col in columns_to_drop:
  if col in existing_columns:
    time_series_df.drop(col, axis=1, inplace=True)

time_series_df.info()
time_series_df.head()

# This line is not needed as 'SOG' has already been removed in the loop above.
#time_series_df.drop(['SOG', 'VesselName'], axis=1, inplace=True)

time_series_df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49142 entries, 0 to 49141
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BaseDateTime  49142 non-null  datetime64[ns]
#  1   LAT           49142 non-null  float64
#  2   LON           49142 non-null  float64
#  3   COG           49142 non-null  float64
#  4   Heading       49142 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 2.2 MB
# <class 'pandas.core.frame.DataFrame'>
# Index: 49142 entries, 0 to 49141
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BaseDateTime  49142 non-null  datetime64[ns]
#  1   LAT           49142 non-null  float64
#  2   LON           49142 non-null  float64
#  3   COG           49142 non-null  float64
#  4   Heading       49142 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 2.2 MB
# ...

# %%
time_series_df = time_series_df[time_series_df['COG']!=0]





time_series_df.head()





time_series_df.info()




plt.plot( time_series_df['BaseDateTime'], time_series_df['COG'])





plt.plot( time_series_df['BaseDateTime'], time_series_df['COG'])
plt.gcf().autofmt_xdate()
plt.show()





time_series_df = time_series_df.reset_index(drop=True)





time_series_df.head()




len(time_series_df[(time_series_df['Heading']==0)])





plt.plot( time_series_df['BaseDateTime'], time_series_df['Heading'])
plt.gcf().autofmt_xdate()
plt.show()





plt.plot( time_series_df['BaseDateTime'], time_series_df['COG'])
plt.gcf().autofmt_xdate()
plt.show()





print(time_series_df.loc[[18000]])





time_series_df.head()





time_series_df.info()





time_series_df.info()
time_series_df.drop(time_series_df[time_series_df['COG'] == 0].index, inplace = True)





data.MMSI.unique()





mv_value = 367702220
param = 'COG'





len(data[data["MMSI"]==mv_value])





len(time_series_df[time_series_df["COG"]==0])





mv_data = data[data['MMSI']==mv_value] # Use data DataFrame instead of time_series_df





mv_data.head()





plt.plot( mv_data['BaseDateTime'], mv_data['COG'])
plt.gcf().autofmt_xdate()
plt.show()




plt.plot( mv_data['BaseDateTime'], mv_data['COG'])
plt.gcf().autofmt_xdate()
plt.show()





# mv_data.reset_index(inplace=True)
mv_data = mv_data.drop(['MMSI','LAT', 'LON'], axis=1)
mv_data.head()





mv_data = mv_data[mv_data['COG'].notna()]
mv_data.info()





mv_data.head()





import warnings
mv_data = mv_data.set_index(['BaseDateTime'])
mv_data.index = pd.to_datetime(mv_data.index)

# Remove the 'VesselName' column from mv_data
mv_data = mv_data.drop('VesselName', axis=1)

names=mv_data.columns
# Resample the entire dataset by daily average
# mv_data.reset_index(inplace=True)

# Convert all columns to numeric type, coerce errors to NaN
mv_data = mv_data.apply(pd.to_numeric, errors='coerce')

rollstd = mv_data.resample(rule='D').std()
rollstd = mv_data.resample(rule='D').mean()
rollstd.head()
rollstd = mv_data.resample(rule='D').std()
# Plot time series for each sensor with its mean and standard deviation
for name in names:
    _ = plt.figure(figsize=(18,3))
    _ = plt.plot(mv_data[name], color='blue', label='Original')
    _ = plt.plot(rollstd[name], color='red', label='Rolling Mean')
    _ = plt.plot(rollstd[name], color='black', label='Rolling Std' )
    _ = plt.legend(loc='best')
    _ = plt.title(name)
    plt.show()




from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer # Import the SimpleImputer

df2 = mv_data
names=df2.columns
x = mv_data[names]
x_cleaned = x.dropna(subset=['COG'])

pca = PCA()

# Create an imputer to fill missing values with the mean
imputer = SimpleImputer(strategy='mean')


# Add the imputer to the pipeline
pipeline = make_pipeline(scaler, imputer, pca)

principalComponents = pipeline.fit_transform(x_cleaned) #This line has changed

pipeline.fit_transform(x_cleaned)

# Now you can access the explained variance
features = range(pca.n_components_)
_ = plt.figure(figsize=(15, 5))
_ = plt.bar(features, pca.explained_variance_)
_ = plt.xlabel('PCA feature')
_ = plt.ylabel('Variance')
_ = plt.xticks(features)
_ = plt.title("Importance of the Principal Components based on inertia")
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49142 entries, 0 to 49141
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BaseDateTime  49142 non-null  datetime64[ns]
#  1   LAT           49142 non-null  float64
#  2   LON           49142 non-null  float64
#  3   COG           49142 non-null  float64
#  4   Heading       49142 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(1)
# memory usage: 1.9 MB
#              BaseDateTime       LAT       LON    COG  Heading
# 18000 2022-03-31 00:04:07  28.93491 -95.33126  237.6      137
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49142 entries, 0 to 49141
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   BaseDateTime  49142 non-null  datetime64[ns]
#  1   LAT           49142 non-null  float64
#  2   LON           49142 non-null  float64
# ...

# %%
pipeline = make_pipeline(imputer, pca)

principalComponents = pipeline.fit_transform(x_cleaned)
# The number of columns should match the number of components
principalDf = pd.DataFrame(data = principalComponents, columns = ['pc1']) # Only one pc
mv_data['pc1']=pd.Series(principalDf['pc1'].values, index=mv_data.index)

from statsmodels.tsa.stattools import adfuller
# Run Augmented Dickey Fuller Test
result = adfuller(principalDf['pc1'])
# Print p-value
print(result[1])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_base.py:598: UserWarning: Skipping features without any observed values: ['IMO' 'CallSign' 'Draft' 'TransceiverClass']. At least one non-missing value is needed for imputation with strategy='mean'.
#   warnings.warn(
# 0.5839212078834298

# %%
# Compute change in daily mean
pca1 = principalDf['pc1'].pct_change()
# Compute autocorrelation
autocorrelation = pca1.dropna().autocorr()
print('Autocorrelation is: ', autocorrelation)
# Out:
# Autocorrelation is:  -0.22213702289939466

# %%
from statsmodels.graphics.tsaplots import plot_acf

# Calculate the maximum number of lags based on the length of pca1
max_lags = len(pca1.dropna()) - 1

# Plot the autocorrelation with the adjusted lags
plot_acf(pca1.dropna(), lags=min(20, max_lags), alpha=0.05)

# %%
# Calculate outlier bounds for pc1
q1_pc1, q3_pc1 = mv_data['pc1'].quantile([0.25, 0.75])
iqr_pc1 = q3_pc1 - q1_pc1
lower_pc1 = q1_pc1 - (1.5*iqr_pc1)
upper_pc1 = q3_pc1 + (1.5*iqr_pc1)
lower_pc1, upper_pc1
# Out:
# (-227.61210649894088, 240.58981956658926)

# %%
mv_data['anomaly_pc1'] = ((mv_data['pc1']>upper_pc1) | (mv_data['pc1']<lower_pc1)).astype('int')
mv_data['anomaly_pc1'].value_counts()
# Out:
# anomaly_pc1
# 0    11
# Name: count, dtype: int64

# %%
outliers_pc1 = mv_data.loc[(mv_data['pc1']>upper_pc1) | (mv_data['pc1']<lower_pc1), 'pc1']
len(outliers_pc1)/len(mv_data)
# Out:
# 0.0

# %%
mv_data.head()
# Out:
#                      SOG    COG  Heading  IMO  CallSign  VesselType  Status  \
# BaseDateTime
# 2022-03-31 00:00:01  0.1  226.5      340  NaN       NaN        31.0    12.0
# 2022-03-31 00:01:11  0.1  245.3      341  NaN       NaN        31.0    12.0
# 2022-03-31 00:02:21  0.0   78.1      341  NaN       NaN        31.0    12.0
# 2022-03-31 00:03:31  0.0  278.8      340  NaN       NaN        31.0    12.0
# 2022-03-31 00:05:51  0.0  312.2      340  NaN       NaN        31.0    12.0
#
#                      Length  Width  Draft  Cargo  TransceiverClass  \
# BaseDateTime
# 2022-03-31 00:00:01    21.0    8.0    NaN   57.0               NaN
# 2022-03-31 00:01:11    21.0    8.0    NaN   57.0               NaN
# 2022-03-31 00:02:21    21.0    8.0    NaN   57.0               NaN
# 2022-03-31 00:03:31    21.0    8.0    NaN   57.0               NaN
# 2022-03-31 00:05:51    21.0    8.0    NaN   57.0               NaN
#
#                             pc1  anomaly_pc1
# BaseDateTime
# ...

# %%
a = mv_data[mv_data['anomaly_pc1'] == 1] #anomaly

plt.figure(figsize=(18,6))
plt.plot(mv_data[param], color='blue', label='Normal')
plt.plot(a[param], linestyle='none', marker='X', color='red', markersize=12, label='Anomaly1')

plt.xlabel('Date and Time')
plt.ylabel(param)
plt.title(param +' Anomalies')
plt.legend(loc='best')
plt.show();
data1 = a

# %%
from sklearn.cluster import KMeans
# I will start k-means clustering with k=2 as I already know that there are 3 classes of "NORMAL" vs
# "NOT NORMAL" which are combination of BROKEN" and"RECOVERING"
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(principalDf.values)
labels = kmeans.predict(principalDf.values)
unique_elements, counts_elements = np.unique(labels, return_counts=True)
clusters = np.asarray((unique_elements, counts_elements))
plt.figure(figsize = (9, 7))
plt.bar(clusters[0], clusters[1], tick_label=clusters[0])
plt.xlabel('Clusters')
plt.ylabel('Number of points')
plt.title('Number of points in each cluster')
plt.show()

# %%
def getDistanceByPoint(data, model):
    """ Function that calculates the distance between a point and centroid of a cluster,
            returns the distances in pandas series"""
    distance = []
    for i in range(0,len(data)):
        Xa = np.array(data.loc[i])
        Xb = model.cluster_centers_[model.labels_[i]-1]
        distance.append(np.linalg.norm(Xa-Xb))
    return pd.Series(distance, index=data.index)
outliers_fraction = 0.05
# get the distance between each point and its nearest centroid. The biggest distances are considered as anomaly
distance = getDistanceByPoint(principalDf, kmeans)
# number of observations that equate to the 13% of the entire data set
number_of_outliers = int(outliers_fraction*len(distance))
# Take the minimum of the largest 13% of the distances as the threshold
threshold = distance.nlargest(number_of_outliers).min()
# anomaly1 contain the anomaly result of the above method Cluster (0:normal, 1:anomaly)
principalDf['anomaly1'] = (distance >= threshold).astype(int)
principalDf.head()
# Out:
#           pc1  anomaly1
# 0   22.164113         0
# 1   40.963007         0
# 2 -126.236882         0
# 3   74.464092         0
# 4  107.864071         0

# %%
principalDf['anomaly1'].value_counts()
# Out:
# anomaly1
# 0    11
# Name: count, dtype: int64

# %%
mv_data['anomaly1'] = pd.Series(principalDf['anomaly1'].values, index=mv_data.index)
a = mv_data[mv_data['anomaly1'] == 1] #anomaly

plt.figure(figsize=(18,6))
plt.plot(mv_data[param], color='blue', label='Normal')
plt.plot(a[param], linestyle='none', marker='X', color='red', markersize=12, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel(param)
plt.title('Anomalies')
plt.legend(loc='best')
plt.show();
data3 = a

# %%
# Import IsolationForest
from sklearn.ensemble import IsolationForest
# Assume that 13% of the entire data set are anomalies
outliers_fraction = 0.05
model =  IsolationForest(contamination=outliers_fraction)
model.fit(principalDf.values)
principalDf['anomaly1'] = pd.Series(model.predict(principalDf.values))
mv_data['anomaly1'] = pd.Series(principalDf['anomaly1'].values, index=mv_data.index)
a = mv_data.loc[mv_data['anomaly1'] == -1] #anomaly
plt.figure(figsize=(18,6))
plt.plot(mv_data[param], color='blue', label='Normal')
plt.plot(a[param], linestyle='none', marker='X', color='red', markersize=12, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel(param +'Reading')
plt.title('Anomalies')
plt.legend(loc='best')
plt.show();
data4 = a

# %%
mv_data['anomaly1'].value_counts()
a.head()
# Out:
#                      SOG   COG  Heading  IMO  CallSign  VesselType  Status  \
# BaseDateTime
# 2022-03-31 00:02:21  0.0  78.1      341  NaN       NaN        31.0    12.0
#
#                      Length  Width  Draft  Cargo  TransceiverClass  \
# BaseDateTime
# 2022-03-31 00:02:21    21.0    8.0    NaN   57.0               NaN
#
#                             pc1  anomaly_pc1  anomaly1
# BaseDateTime
# 2022-03-31 00:02:21 -126.236882            0        -1

# %%
def intersection(lst1, lst2,lst3,lst4):
    lst5 = [value for value in lst2 if value in lst1]
    lst6 = [value for value in lst3 if value in lst5]
    lst7 = [value for value in lst4 if value in lst6]
    return lst7
time_common = intersection(data1.index.unique() , data4.index.unique() , data3.index.unique() , data4.index.unique() )
time_df = pd.DataFrame(columns = mv_data.columns, index = time_common)
for time in time_common:
    time_df.loc[time] = mv_data.loc[time]
plt.figure(figsize=(18,6))
plt.plot(mv_data[param], color='blue', label='Normal')
plt.plot(time_df[param], linestyle='none', marker='X', color='red', markersize=12, label='Anomaly')
plt.xlabel('Date and Time')
plt.ylabel(param +'Reading')
plt.title('Anomalies')
plt.legend(loc='best')
plt.show();
